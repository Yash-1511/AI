# %% [markdown]
# # Matplotlib Tutorial

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]

# %%
plt.xlabel('X points')
plt.ylabel('Y points')
plt.title("Demo chart")
plt.plot(x,y)
